# %% [markdown]
# 1. 知道要获取什么数据，并知道数据在哪
# 2. 分析目标的数据结构，选择技术
# 3. 编写代码，保存数据

# %%
import requests
url = 'https://webfs.hw.kugou.com/202401201629/793d236ba8b3af5632ec60f026daeabc/v2/106ec000715c5c62aae36b347b296642/part/0/960125/G353/M04/6D/39/clip_QZUEAGUGzH6APNfDADDZR9Od_zo439.mp3'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'}
request = requests.get('https://www.kugou.com/mixsong/9pnrdwea.html', headers=headers)

# %%
request.content
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n    <meta charset="UTF-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n    <title>\xe6\x96\x97\xe5\x85\xbd\xe5\x9c\xba_\xe5\xb0\xb9\xe6\x98\x94\xe7\x9c\xa0_\xe9\xab\x98\xe9\x9f\xb3\xe8\xb4\xa8\xe5\x9c\xa8\xe7\xba\xbf\xe8\xaf\x95\xe5\x90\xac_\xe6\x96\x97\xe5\x85\xbd\xe5\x9c\xba\xe6\xad\x8c\xe8\xaf\x8d|\xe6\xad\x8c\xe6\x9b\xb2\xe4\xb8\x8b\xe8\xbd\xbd_\xe9\x85\xb7\xe7\x8b\x97\xe9\x9f\xb3\xe4\xb9\x90</title>\n    <meta name="keywords" content="\xe6\x96\x97\xe5\x85\xbd\xe5\x9c\xba,\xe5\xb0\xb9\xe6\x98\x94\xe7\x9c\xa0,\xe6\x96\x97\xe5\x85\xbd\xe5\x9c\xba\xe4\xb8\x8b\xe8\xbd\xbd,\xe6\x96\x97\xe5\x85\xbd\xe5\x9c\xba\xe6\xad\x8c\xe8\xaf\x8d" />\n    <meta name="description" content="\x
# ...

# %%
with open('01_music/ganghaoyujianni.mp3','wb') as f:
    f.write(request.content)

# %%
a = 'https:\/\/webfs.hw.kugou.com\/202401201810\/999085f5ed475b4fefc3d1c6198f3f94\/v2\/e1079a08f2944e6f2b0e3129b62aca73\/part\/0\/960125\/G323\/M08\/B7\/C5\/clip_I5UEAGTA13qAfO97ADVe1Hb0r80949.mp3'

# %%
href="https://www.kugou.com/mixsong/9pnrdwea.html"
